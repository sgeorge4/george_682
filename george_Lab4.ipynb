# %% [markdown]
# ###Stephanie George
# ##July 15, 2019
# ##GEOG682 - Lab 4

# %%
import rasterio
from rasterio import plot
import matplotlib.pyplot as plt

from rasterio.merge import merge
from rasterio.plot import show

# %%
satdat1 = rasterio.open("image1.tif")
satdat2 = rasterio.open("image2.tif")

# %%
satdat1.count
satdat2.count
# Out:
# 3

# %%
satdat1.width
satdat2.width
# Out:
# 5490

# %%
satdat1.height
satdat2.height
# Out:
# 5490

# %%
satdat1.crs
satdat2.crs
# Out:
# CRS.from_epsg(32618)

# %% [markdown]
# EPSG:32618 WGS 84 / UTM zone 18N

# %%
plot.show(satdat1, cmap='terrain')
plot.show(satdat2, cmap='terrain')

# %%
#plot each band of the image individually
fig, (axr, axg, axb) = plt.subplots(1,3, figsize=(20,15))
plot.show((satdat1, 3), ax=axr, cmap='Reds', title='Red')
plot.show((satdat1, 2), ax=axg, cmap='Greens', title='Green')
plot.show((satdat1, 1), ax=axb, cmap='Blues', title='Blue')

# %%
srcs_to_mosaic = [satdat1, satdat2]
mosaic, out_trans = merge(srcs_to_mosaic)
show(mosaic)
